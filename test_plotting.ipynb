# %%
from plotter import nbPlotter
from easyCore.Elements.HigherLevel.Phase import Phase

# %%
p = Phase('test')
p.cell.length_c = 4
p.spacegroup.space_group_HM_name = 'P 6'
p.add_atom('Cu', 'Cu2+', 1, 0, 0, 0)
w = nbPlotter(p)
w.extent = [2, 2, 1]
w.max_distance = 4
w.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7EFE897FF7B8>

# %%
w = nbPlotter(p)
w.extent = [2, 2, 1]
w.max_distance = 3
w.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7EFE843146A0>
